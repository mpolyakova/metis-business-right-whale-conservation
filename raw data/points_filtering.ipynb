# %%
import pandas  as pd

# %%
df = pd.read_csv('obis_seamap_dataset_513_points.csv')
# Out:
# /opt/anaconda3/envs/metis/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3169: DtypeWarning: Columns (5,6,17,54,60) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.date_time.head()
# Out:
# 0    1998-05-16 14:31:20
# 1    1998-05-16 15:23:42
# 2    2003-06-24 08:33:15
# 3    2003-06-07 10:18:54
# 4    2007-10-26 11:52:44
# Name: date_time, dtype: object

# %%
df.columns
df.date_local.unique()
df.info()
print(df.common_name.unique())

df['dt']=pd.to_datetime(df['date_time'], format='%Y-%m-%d %H:%M:%S')
df.dt.head()
df['date']= pd.to_datetime(df['date_local'], format='%Y-%m-%d')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88579 entries, 0 to 88578
# Data columns (total 73 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   dataset_id         88579 non-null  int64
#  1   row_id             88579 non-null  object
#  2   latitude           88579 non-null  float64
#  3   longitude          88579 non-null  float64
#  4   species_name       88579 non-null  object
#  5   scientific_name    45405 non-null  object
#  6   common_name        45405 non-null  object
#  7   itis_tsn           45405 non-null  float64
#  8   group_size         88577 non-null  float64
#  9   series_id          0 non-null      float64
#  10  date_time          88579 non-null  object
#  11  timezone           88579 non-null  float64
#  12  ds_type            88579 non-null  object
#  13  platform           88579 non-null  object
#  14  provider           88579 non-null  object
#  15  lprecision         88579 non-null  int64
# ...

# %%
max(df['dt'])
min(df['dt'])
df['year'] = df.dt.dt.year
df.groupby(['year']).describe()
df2 = df[df['year']==2015]
df2016 = df[df['year']==2016]

# %%
df2.common_name.unique()
df.columns
# Out:
# Index(['dataset_id', 'row_id', 'latitude', 'longitude', 'species_name',
#        'scientific_name', 'common_name', 'itis_tsn', 'group_size', 'series_id',
#        'date_time', 'timezone', 'ds_type', 'platform', 'provider',
#        'lprecision', 'tprecision', 'oceano', 'notes', 'last_mod', 'id',
#        'source', 'plane', 'date_local', 'time_local', 'event_number',
#        'flight_type', 'legtype', 'legstage', 'psb_legstage', 'altitude',
#        'heading', 'speed', 'sst_c', 'beaufort', 'visibilty_code',
#        'visibilty_nm', 'cloud_code', 'cloud_percent', 'glare_l', 'glare_r',
#        'quality_l', 'quality_r', 'id_reliability', 'sighting_number', 'spcode',
#        'calves', 'bearing', 'actual_heading', 'relative_heading', 'observer',
#        'obs_position', 'angle', 'cue', 'b1_final_code', 'b2_final_code',
#        'b3_final_code', 'b4_final_code', 'b5_final_code', 'photos',
#        'effort_comments', 'sighting_comments', 'edit1', 'edit2', 'edit3',
# ...

# %%
df2.sighting_comments.unique()
# Out:
# array([nan, 'R/V Bigelow', 'change to mod gear', 'change to heavy gear',
#        'end light gear', 'alt obs', 'beg light gear', 'resight s13',
#        'small bulk carrier', 'clam dredge', 'car carrier',
#        'Maersk Shipping Co', 'R/V Ibis', 'net and orange float',
#        'really dark lg fish', 'alt obs small', 'resight s227',
#        'no gs recorded', '2 buoys + 70ft line', 'resight s39',
#        'beg mod gear', 'foam patch dead unid from track', 'resight s258',
#        'resight s1', 'end mod gear', '25ft of line',
#        'change to light gear', 'tuna', 'end heavy gear', 'resight s104',
#        'dup from st s87', 'dup from st', 'poss raft from track',
#        'resight', 'psi', 'scalloper', 'fin est 4 thru 0699',
#        'no dec turning', 'no dec spread out', 'ap s57 thru 1451',
#        'fin est 2 thru 0670', 'small dark', 'ap new', 'ech',
#        'fin est 1 thru 0648', 'unid from track', 'ap s49 psi',
#        'fin est 2 thru 0683 1 not ph', 'fin est 1 thru 0566',
# ...

# %%
df2.head()
df3 = df2[['latitude','longitude','species_name','common_name','group_size','calves','year', 'date']]

# %%
#df3.to_csv('2015_points.csv')
df2017 = df[df['year']==2017]
df2016_2 = df2017[['latitude','longitude','species_name','common_name','group_size','calves','year', 'date']]
df2016_2.to_csv('2017_points.csv')

# %%
lf = pd.read_csv('obis_seamap_dataset_513_lines.csv')
# Out:
# /opt/anaconda3/envs/metis/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3169: DtypeWarning: Columns (58,59,66,67,68,69,70,71,72,73) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
lf.head()
lf['date']= pd.to_datetime(lf['date_local'], format='%Y-%m-%d')

# %%
lf[lf.spcode=='BLWH']
# Out:
#         dataset_id      row_id  series_id  longitude_begin  latitude_begin  \
# 28404          514   514_28405        NaN       -70.074195       42.936921
# 63064          514   514_63065        NaN       -68.499600       43.430300
# 96310          514   514_96311        NaN       -70.154690       43.137170
# 102912         514  514_102913        NaN       -69.239860       42.625910
# 109593         514  514_109594        NaN       -69.896600       42.314900
# 218213         514  514_218214        NaN       -62.083890       48.164960
# 255485         514  514_255486        NaN       -64.321820       49.417300
# 255505         514  514_255506        NaN       -64.356610       49.484360
# 264527         514  514_264528        NaN       -62.808980       47.733400
# 329723         514  514_329724        NaN       -64.011700       47.706200
# 331661         514  514_331662        NaN       -63.917000       47.803200
# ...

# %%
rl = lf[lf['spcode'].isin(['RIWH','BLWH'])]

# %%
rl.info()
rl.to_csv('right_blue_whale_tracks.csv')
# rl[['longtitude_begin','latitude_begin','longtitude_end','latitude_end','datetime_begin','datetime_end','length_km','date_local','spcode','']]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11354 entries, 313 to 1031999
# Data columns (total 76 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   dataset_id         11354 non-null  int64
#  1   row_id             11354 non-null  object
#  2   series_id          0 non-null      float64
#  3   longitude_begin    11354 non-null  float64
#  4   latitude_begin     11354 non-null  float64
#  5   longitude_end      11354 non-null  float64
#  6   latitude_end       11354 non-null  float64
#  7   datetime_begin     11354 non-null  object
#  8   datetime_end       11354 non-null  object
#  9   length_km          11354 non-null  float64
#  10  speed_kph          11354 non-null  float64
#  11  eff_status         11354 non-null  object
#  12  ds_type            11354 non-null  object
#  13  id_obs             11354 non-null  int64
#  14  beglat             11354 non-null  float64
# ...

# %%
rl.cue.unique()
# Out:
# array([nan, 'ANIMAL', 'BLOW', 'SPLASH', 'OTHER', 'VESSEL/GEAR',
#        'FOOTPRINT', 'DISTURBANCE', 'WINDROWS'], dtype=object)

# %%
df.head()
df['dt']=pd.to_datetime(df['date_time'], format='%Y-%m-%d %H:%M:%S')
df['date']= pd.to_datetime(df['date_local'], format='%Y-%m-%d')
df['year'] = df.dt.dt.year

rw = df[df['species_name'].isin(['RIWH','BLWH'])]
w = df[df['species_name'].str.contains('WH', na=True)]

# %%
df[df['species_name'].isin(['BLWH'])]
# Out:
#        dataset_id     row_id   latitude  longitude species_name  \
# 3483          513  513_19183  40.561584 -67.714485         BLWH
# 3971          513   513_7817  40.589970 -69.105030         BLWH
# 8197          513  513_90305  49.417300 -64.321820         BLWH
# 8198          513  513_90306  49.484360 -64.356610         BLWH
# 8213          513  513_95480  48.649520 -63.904910         BLWH
# 11145         513  513_93374  48.283000 -63.828800         BLWH
# 11191         513  513_95466  48.323340 -63.970180         BLWH
# 11368         513  513_90544  48.164960 -62.083890         BLWH
# 11530         513  513_70232  45.845640 -59.252820         BLWH
# 11690         513  513_70304  45.836940 -59.283250         BLWH
# 11873         513  513_93338  47.873100 -63.836500         BLWH
# 12219         513  513_96628  47.461170 -63.670010         BLWH
# 12220         513  513_96629  47.469440 -63.681330         BLWH
# 12328         513  513_93260  47.706200 -64.011700         BLWH
# ...

# %%
w.info()
w[['latitude','longitude','species_name','common_name','group_size','calves','year', 'date']].to_csv('whales.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19694 entries, 22 to 88572
# Data columns (total 73 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   dataset_id         19694 non-null  int64
#  1   row_id             19694 non-null  object
#  2   latitude           19694 non-null  float64
#  3   longitude          19694 non-null  float64
#  4   species_name       19694 non-null  object
#  5   scientific_name    19245 non-null  object
#  6   common_name        19245 non-null  object
#  7   itis_tsn           19245 non-null  float64
#  8   group_size         19692 non-null  float64
#  9   series_id          0 non-null      float64
#  10  date_time          19694 non-null  object
#  11  timezone           19694 non-null  float64
#  12  ds_type            19694 non-null  object
#  13  platform           19694 non-null  object
#  14  provider           19694 non-null  object
#  15  lprecision         19694 non-null  int64
# ...

# %%
rw.info()
rw.to_csv('right_blue_whales.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2727 entries, 1664 to 87380
# Data columns (total 73 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   dataset_id         2727 non-null   int64
#  1   row_id             2727 non-null   object
#  2   latitude           2727 non-null   float64
#  3   longitude          2727 non-null   float64
#  4   species_name       2727 non-null   object
#  5   scientific_name    2727 non-null   object
#  6   common_name        2727 non-null   object
#  7   itis_tsn           2727 non-null   float64
#  8   group_size         2727 non-null   float64
#  9   series_id          0 non-null      float64
#  10  date_time          2727 non-null   object
#  11  timezone           2727 non-null   float64
#  12  ds_type            2727 non-null   object
#  13  platform           2727 non-null   object
#  14  provider           2727 non-null   object
# ...
